# %% [markdown]
# # Selecting Time Series Data
#
# Broadly speaking, time series data are points of data gathered over time (datetimes using pandas terminology). The time order is meaningful and there is only one observation per unit of time typically. Each unit of time often uniquely identifies each record. Often, time is evenly spaced between each data point.
#
# Examples of time series data include stock market closing prices, levels of CO2 in the atmosphere, unemployment rates, and airplane altitude. pandas has good functionality with regards to analyzing time series data, aggregating over different time periods, sampling different periods of time, and more. Let's begin by reading in 20 years of stock market data, putting the `date` column in the index.

# %%
import pandas as pd
df = pd.read_csv('../data/stocks/stocks10.csv', parse_dates=['date'], 
                 index_col='date')
df.head(3)
# Out:
#              MSFT  AAPL    SLB   AMZN  TSLA    XOM    WMT      T  FB   V
# date
# 1999-10-25  29.84  2.32  17.02  82.75   NaN  21.45  38.99  16.78 NaN NaN
# 1999-10-26  29.82  2.34  16.65  81.25   NaN  20.89  37.11  17.28 NaN NaN
# 1999-10-27  29.33  2.38  16.52  75.94   NaN  20.80  36.94  18.27 NaN NaN

# %% [markdown]
# ## Set the datetime column as the index
#
# If you do have time series data where the values of one datetime column uniquely identify each row, then it's best to use this column as the index. pandas provides extra functionality to DataFrames that have a datetime index.
#
# ### DateTimeIndex
#
# Setting a datetime column as the index creates a DateTimeIndex.

# %%
idx = df.index
type(idx)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %% [markdown]
# Like other index objects, items may be selected with slice notation.

# %%
idx[:5]
# Out:
# DatetimeIndex(['1999-10-25', '1999-10-26', '1999-10-27', '1999-10-28',
#                '1999-10-29'],
#               dtype='datetime64[ns]', name='date', freq=None)

# %% [markdown]
# You can directly call specific datetime methods on DateTimeIndex objects just like you can with the `dt` accessor on datetime Series. Let's get the year, month, and day name directly from this index object. The first five values of each attribute are returned.

# %%
idx.year[:5]
# Out:
# Index([1999, 1999, 1999, 1999, 1999], dtype='int32', name='date')

# %%
idx.month[:5]
# Out:
# Index([10, 10, 10, 10, 10], dtype='int32', name='date')

# %%
idx.day_name()[:5]
# Out:
# Index(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday'], dtype='object', name='date')

# %% [markdown]
# ## Easy subset selection with a DateTimeIndex
#
# One big advantage of a DateTimeIndex is the ability to select subsets of data without using boolean indexing. We can use strings to represent specific datetimes and pass those strings to the `loc` indexer. Here, we select the row of data for January 5th, 2017.

# %%
df
# Out:
#               MSFT    AAPL    SLB     AMZN    TSLA    XOM     WMT      T  \
# date
# 1999-10-25   29.84    2.32  17.02    82.75     NaN  21.45   38.99  16.78
# 1999-10-26   29.82    2.34  16.65    81.25     NaN  20.89   37.11  17.28
# 1999-10-27   29.33    2.38  16.52    75.94     NaN  20.80   36.94  18.27
# 1999-10-28   29.01    2.43  16.59    71.00     NaN  21.19   38.85  19.79
# 1999-10-29   29.88    2.50  17.21    70.62     NaN  21.47   39.25  20.00
# ...            ...     ...    ...      ...     ...    ...     ...    ...
# 2019-10-18  137.41  236.41  32.31  1757.51  256.95  67.61  119.14  38.47
# 2019-10-21  138.43  240.51  33.59  1785.66  253.50  68.74  119.74  38.23
# 2019-10-22  136.37  239.96  34.82  1765.73  255.58  69.09  119.58  38.17
# 2019-10-23  137.24  243.18  35.33  1762.17  254.68  69.75  119.35  37.74
# 2019-10-24  139.81  242.46  34.30  1777.40  298.19  69.07  119.12  37.04
#
#                 FB       V
# date
# 1999-10-25     NaN     NaN
# 1999-10-26     NaN     NaN
# 1999-10-27     NaN     NaN
# 1999-10-28     NaN     NaN
# 1999-10-29     NaN     NaN
# ...            ...     ...
# 2019-10-18  185.85  175.71
# 2019-10-21  189.76  176.43
# 2019-10-22  182.34  170.86
# 2019-10-23  186.15  171.32
# 2019-10-24  184.92  175.57
#
# [5033 rows x 10 columns]

# %%
df.loc['2017-1-5']
# Out:
# MSFT     59.23
# AAPL    111.73
# SLB      76.93
# AMZN    780.45
# TSLA    226.75
# XOM      79.11
# WMT      64.88
# T        36.08
# FB      120.67
# V        79.61
# Name: 2017-01-05 00:00:00, dtype: float64

# %% [markdown]
# Note that we did not have to convert the string to a datetime object first. pandas implicitly understood that the string was a datetime.

# %% [markdown]
# ### Partial string matching to select entire periods of time
#
# You can select entire periods of time by using a string with less precision. Here, we select all of the rows from the month of February, 2017.

# %%
df.loc['2017-2'].head(3)
# Out:
#              MSFT    AAPL    SLB    AMZN    TSLA    XOM    WMT      T      FB  \
# date
# 2017-02-01  60.45  123.36  75.01  832.35  249.24  74.10  62.09  35.99  133.23
# 2017-02-02  60.06  123.15  74.35  839.95  251.55  74.55  62.53  35.24  130.84
# 2017-02-03  60.54  123.68  74.40  810.20  251.33  74.63  62.34  35.30  130.98
#
#                 V
# date
# 2017-02-01  80.94
# 2017-02-02  80.80
# 2017-02-03  84.51

# %% [markdown]
# Below, we select the entire year 2016.

# %%
df.loc['2016'].head(3)
# Out:
#              MSFT   AAPL    SLB    AMZN    TSLA    XOM    WMT      T      FB  \
# date
# 2016-01-04  50.71  98.74  60.79  636.99  223.41  66.84  55.99  27.65  102.22
# 2016-01-05  50.94  96.27  61.07  633.79  223.43  67.41  57.32  27.85  102.73
# 2016-01-06  50.01  94.38  59.49  632.65  219.04  66.85  57.90  27.81  102.97
#
#                 V
# date
# 2016-01-04  73.61
# 2016-01-05  74.16
# 2016-01-06  73.19

# %% [markdown]
# ### Slicing with partial string matching
#
# Use slice notation to select a specific date range. Below, we select from March 28, 2017 through April 3, 2017. Note that the stop value is inclusive.

# %%
df.loc['2017-3-28':'2017-4-3']
# Out:
#              MSFT    AAPL    SLB    AMZN    TSLA    XOM    WMT      T      FB  \
# date
# 2017-03-28  62.45  138.38  71.06  856.00  277.45  73.78  66.41  35.56  141.76
# 2017-03-29  62.62  138.68  71.39  874.32  277.38  73.94  66.81  35.47  142.65
# 2017-03-30  62.85  138.50  70.63  876.34  277.92  75.46  67.61  35.74  142.41
# 2017-03-31  62.99  138.24  70.87  886.54  278.30  73.93  68.07  35.56  142.05
# 2017-04-03  62.70  138.28  70.50  891.51  298.52  73.99  67.83  35.57  142.28
#
#                 V
# date
# 2017-03-28  87.66
# 2017-03-29  87.72
# 2017-03-30  87.55
# 2017-03-31  87.41
# 2017-04-03  87.90

# %% [markdown]
# ### Selecting date ranges along with specific columns
#
# The `loc` indexer allows you select specific columns along with ranges of dates. Here, we select the month of May, 2017 along with three specific columns.

# %%
df.loc['2017-5', ['SLB', 'T', 'FB']].head()
# Out:
#               SLB      T      FB
# date
# 2017-05-01  65.60  33.86  152.46
# 2017-05-02  64.83  33.73  152.78
# 2017-05-03  64.91  33.25  151.80
# 2017-05-04  64.37  32.92  150.85
# 2017-05-05  65.31  33.39  150.24

# %% [markdown]
# ## Selecting rows at specific frequencies
#
# In addition to selecting consecutive rows, it is possible to select disjoint rows at specific frequencies of time. The `asfreq` method allows you to select very specific intervals, by passing it an **offset alias** as a string. An offset alias determines the frequency of the time series data you would like to sample. The table below shows the most common offset aliases. Reference all of the [offset aliases in the official documentation][1].
#
# | Alias    | Description     |  Alias  |  Description  |
# |:---------|:----------------|:--------|:--------------|
# | `Y`/`A`        | year end        | `D`       | day           |
# | `YS`/`AS`       | year start      | `H`        | hourly       |
# | `Q`        | quarter end     | `T` or `min`   | minutes      |
# | `QS`       | quarter start   | `S`        | seconds      |
# | `M`        | month end     | `L` or `ms`    | milliseconds |
# | `MS`       | month start       | `U` or `us`    | microseconds |
# | `W`        | weekly          | `N`        | nanoseconds  |
#
# [1]: https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#offset-aliases

# %% [markdown]
# Let's say we are interested in selecting the last day of each year. To do so, we choose `'Y'` for the year end frequency. We pass this as a string to the `asfreq` method to return the very last day of each year. Note that `asfreq` only works for DataFrames with a DateTimeIndex.

# %%
df.asfreq('YE').head(8)
# Out:
#              MSFT  AAPL    SLB   AMZN  TSLA    XOM    WMT      T  FB   V
# date
# 1999-12-31  37.68  3.20  18.11  76.12   NaN  23.49  48.21  18.49 NaN NaN
# 2000-12-31    NaN   NaN    NaN    NaN   NaN    NaN    NaN    NaN NaN NaN
# 2001-12-31  21.38  1.37  18.58  10.82   NaN  24.18  40.56  15.52 NaN NaN
# 2002-12-31  16.69  0.89  14.68  18.89   NaN  22.03  35.79  11.13 NaN NaN
# 2003-12-31  17.82  1.33  19.72  52.62   NaN  26.58  37.84  11.20 NaN NaN
# 2004-12-31  19.45  4.01  24.72  44.29   NaN  34.04  38.03  11.62 NaN NaN
# 2005-12-31    NaN   NaN    NaN    NaN   NaN    NaN    NaN    NaN NaN NaN
# 2006-12-31    NaN   NaN    NaN    NaN   NaN    NaN    NaN    NaN NaN NaN

# %% [markdown]
# ### Business offset aliases
#
# In this case, selecting the very last day isn't quite what we want because the stock market is only open on weekdays and December 31st falls on a weekend some years. The `asfreq` method returns one row for each frequency regardless if there is data for that date. All values for rows that do not appear in the DataFrame will be missing.
#
# Most of the offset aliases above can be prepended by the character `'B'` to signify a business offset alias. Business offset aliases only consider the weekdays Monday through Friday. Let's change the offset alias to `'BY'` to signify business year end frequency. Doing so correctly selects the last trading day of each year.

# %%
df.asfreq('BYE').head(8)
# Out:
#              MSFT   AAPL    SLB   AMZN  TSLA    XOM    WMT      T  FB   V
# date
# 1999-12-31  37.68   3.20  18.11  76.12   NaN  23.49  48.21  18.49 NaN NaN
# 2000-12-29  14.00   0.93  26.32  15.56   NaN  25.89  37.23  18.50 NaN NaN
# 2001-12-31  21.38   1.37  18.58  10.82   NaN  24.18  40.56  15.52 NaN NaN
# 2002-12-31  16.69   0.89  14.68  18.89   NaN  22.03  35.79  11.13 NaN NaN
# 2003-12-31  17.82   1.33  19.72  52.62   NaN  26.58  37.84  11.20 NaN NaN
# 2004-12-31  19.45   4.01  24.72  44.29   NaN  34.04  38.03  11.62 NaN NaN
# 2005-12-30  19.27   8.96  36.62  47.15   NaN  38.05  34.12  11.64 NaN NaN
# 2006-12-29  22.32  10.58  48.10  39.46   NaN  52.92  34.16  17.83 NaN NaN

# %% [markdown]
# ### Anchored offset aliases
#
# Let's say we would like to select every Thursday. We'll need to use a slightly different string called an **anchored offset alias**. You can anchor years and quarters to months and weeks to days by placing a dash and the abbreviation of the anchor after the offset alias. For example, `BY-APR` signifies business year frequency ending in April. When anchoring the week, use the three-character abbreviation of the day. Below, we anchor weeks to Thursday. The default anchor for weeks is Sunday.

# %%
df.asfreq('W-THU').head()
# Out:
#              MSFT  AAPL    SLB   AMZN  TSLA    XOM    WMT      T  FB   V
# date
# 1999-10-28  29.01  2.43  16.59  71.00   NaN  21.19  38.85  19.79 NaN NaN
# 1999-11-04  29.61  2.61  17.09  63.06   NaN  21.16  39.03  19.39 NaN NaN
# 1999-11-11  28.93  2.88  17.57  73.00   NaN  22.40  40.03  19.39 NaN NaN
# 1999-11-18  27.42  2.79  18.95  77.94   NaN  23.63  41.38  19.47 NaN NaN
# 1999-11-25    NaN   NaN    NaN    NaN   NaN    NaN    NaN    NaN NaN NaN

# %% [markdown]
# Select the last day of June of each year by using the `A` offset alias and anchoring to the three-character abbreviation of the month. At the time of this writing, the `Y` offset alias, does not allow for anchoring.

# %%
df.asfreq('A-Jun').head()
# Out:
# C:\Users\nealv\AppData\Local\Temp\ipykernel_54096\969211733.py:1: FutureWarning: 'A-Jun' is deprecated and will be removed in a future version, please use 'YE-JUN' instead.
#   df.asfreq('A-Jun').head()
#              MSFT  AAPL    SLB   AMZN  TSLA    XOM    WMT      T  FB   V
# date
# 2000-06-30  25.82  3.26  24.34  36.31   NaN  23.14  40.29  16.87 NaN NaN
# 2001-06-30    NaN   NaN    NaN    NaN   NaN    NaN    NaN    NaN NaN NaN
# 2002-06-30    NaN   NaN    NaN    NaN   NaN    NaN    NaN    NaN NaN NaN
# 2003-06-30  16.60  1.19  16.89  36.32   NaN  22.96  38.15  10.72 NaN NaN
# 2004-06-30  18.60  2.03  23.18  54.40   NaN  29.16  37.62  10.67 NaN NaN

# %% [markdown]
# ## Upsampling - Increasing the number of rows
#
# The above selections choose a specific subset of rows. pandas uses the terminology **downsampling** when selecting a subset of the original data (usually less rows than the original). Instead, we may choose to **upsample** and increase the number of rows. This will lead to many rows of missing values. Both upsampling and downsampling ensure that the rows are evenly spaced units of time. Let's return a DataFrame with a single row for each day of the year. This will create rows all non-trading days (weekends and holidays).

# %%
df.asfreq('D').head(7)
# Out:
#              MSFT  AAPL    SLB   AMZN  TSLA    XOM    WMT      T  FB   V
# date
# 1999-10-25  29.84  2.32  17.02  82.75   NaN  21.45  38.99  16.78 NaN NaN
# 1999-10-26  29.82  2.34  16.65  81.25   NaN  20.89  37.11  17.28 NaN NaN
# 1999-10-27  29.33  2.38  16.52  75.94   NaN  20.80  36.94  18.27 NaN NaN
# 1999-10-28  29.01  2.43  16.59  71.00   NaN  21.19  38.85  19.79 NaN NaN
# 1999-10-29  29.88  2.50  17.21  70.62   NaN  21.47  39.25  20.00 NaN NaN
# 1999-10-30    NaN   NaN    NaN    NaN   NaN    NaN    NaN    NaN NaN NaN
# 1999-10-31    NaN   NaN    NaN    NaN   NaN    NaN    NaN    NaN NaN NaN

# %% [markdown]
# ## Use integers in the offset alias
#
# You can provide more precise offsets by placing an integer in front of the offset alias. These represent a multiple of the offset alias. For example, `'3M'` stands for 3 months and `'15s'` for 15 seconds. To select every 6th Wednesday, we do the following:

# %%
df.asfreq('6W-WED').head()
# Out:
#              MSFT  AAPL    SLB   AMZN  TSLA    XOM    WMT      T  FB   V
# date
# 1999-10-27  29.33  2.38  16.52  75.94   NaN  20.80  36.94  18.27 NaN NaN
# 1999-12-08  29.61  3.43  16.88  88.56   NaN  24.34  40.88  20.50 NaN NaN
# 2000-01-19  34.54  3.32  21.25  66.81   NaN  24.95  44.68  15.46 NaN NaN
# 2000-03-01  29.31  4.06  25.00  65.88   NaN  22.30  34.18  16.01 NaN NaN
# 2000-04-12  25.62  3.41  23.76  56.38   NaN  23.44  43.60  18.02 NaN NaN

# %% [markdown]
# You can also upsample by smaller units than what is present in the index. For instance, '4H' will make a new row for every 4 hours of time.

# %%
df.asfreq('4H').head(8)
# Out:
# C:\Users\nealv\AppData\Local\Temp\ipykernel_54096\1372722146.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   df.asfreq('4H').head(8)
#                       MSFT  AAPL    SLB   AMZN  TSLA    XOM    WMT      T  FB  \
# date
# 1999-10-25 00:00:00  29.84  2.32  17.02  82.75   NaN  21.45  38.99  16.78 NaN
# 1999-10-25 04:00:00    NaN   NaN    NaN    NaN   NaN    NaN    NaN    NaN NaN
# 1999-10-25 08:00:00    NaN   NaN    NaN    NaN   NaN    NaN    NaN    NaN NaN
# 1999-10-25 12:00:00    NaN   NaN    NaN    NaN   NaN    NaN    NaN    NaN NaN
# 1999-10-25 16:00:00    NaN   NaN    NaN    NaN   NaN    NaN    NaN    NaN NaN
# 1999-10-25 20:00:00    NaN   NaN    NaN    NaN   NaN    NaN    NaN    NaN NaN
# 1999-10-26 00:00:00  29.82  2.34  16.65  81.25   NaN  20.89  37.11  17.28 NaN
# 1999-10-26 04:00:00    NaN   NaN    NaN    NaN   NaN    NaN    NaN    NaN NaN
#
#                       V
# date
# 1999-10-25 00:00:00 NaN
# 1999-10-25 04:00:00 NaN
# 1999-10-25 08:00:00 NaN
# 1999-10-25 12:00:00 NaN
# 1999-10-25 16:00:00 NaN
# 1999-10-25 20:00:00 NaN
# 1999-10-26 00:00:00 NaN
# 1999-10-26 04:00:00 NaN

# %% [markdown]
# You can fill in the missing values with the previous or next known values using the `method` parameter which can be set to either `'ffill'` or `'bfill'`. Here we fill the missing values using the previously known value in the column.

# %%
df.asfreq('4H', method='ffill').head(8)
# Out:
# C:\Users\nealv\AppData\Local\Temp\ipykernel_54096\3172148161.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   df.asfreq('4H', method='ffill').head(8)
#                       MSFT  AAPL    SLB   AMZN  TSLA    XOM    WMT      T  FB  \
# date
# 1999-10-25 00:00:00  29.84  2.32  17.02  82.75   NaN  21.45  38.99  16.78 NaN
# 1999-10-25 04:00:00  29.84  2.32  17.02  82.75   NaN  21.45  38.99  16.78 NaN
# 1999-10-25 08:00:00  29.84  2.32  17.02  82.75   NaN  21.45  38.99  16.78 NaN
# 1999-10-25 12:00:00  29.84  2.32  17.02  82.75   NaN  21.45  38.99  16.78 NaN
# 1999-10-25 16:00:00  29.84  2.32  17.02  82.75   NaN  21.45  38.99  16.78 NaN
# 1999-10-25 20:00:00  29.84  2.32  17.02  82.75   NaN  21.45  38.99  16.78 NaN
# 1999-10-26 00:00:00  29.82  2.34  16.65  81.25   NaN  20.89  37.11  17.28 NaN
# 1999-10-26 04:00:00  29.82  2.34  16.65  81.25   NaN  20.89  37.11  17.28 NaN
#
#                       V
# date
# 1999-10-25 00:00:00 NaN
# 1999-10-25 04:00:00 NaN
# 1999-10-25 08:00:00 NaN
# 1999-10-25 12:00:00 NaN
# 1999-10-25 16:00:00 NaN
# 1999-10-25 20:00:00 NaN
# 1999-10-26 00:00:00 NaN
# 1999-10-26 04:00:00 NaN

# %% [markdown]
# ### No duplicates are allowed and dates must be ordered
#
# Upsampling and downsampling only work when there are no duplicate dates and when the data is ordered. Let's take a look at the employee dataset which has a datetime column, but is not time series data.

# %%
emp = pd.read_csv('../data/employee.csv', parse_dates=['hire_date'])
emp = emp.set_index('hire_date')
emp.head(3)
# Out:
#                             dept                       title    salary   sex  \
# hire_date
# 2001-12-03                Police             POLICE SERGEANT  87545.38  Male
# 2010-11-15                 Other  ASSISTANT CITY ATTORNEY II  82182.00  Male
# 2006-01-09  Houston Public Works     SENIOR SLUDGE PROCESSOR  49275.00  Male
#
#                 race
# hire_date
# 2001-12-03     White
# 2010-11-15  Hispanic
# 2006-01-09     Black

# %% [markdown]
# If we try and sample it by year, we get an error.

# %%
emp
# Out:
#                                dept                          title    salary  \
# hire_date
# 2001-12-03                   Police                POLICE SERGEANT  87545.38
# 2010-11-15                    Other     ASSISTANT CITY ATTORNEY II  82182.00
# 2006-01-09     Houston Public Works        SENIOR SLUDGE PROCESSOR  49275.00
# 1997-05-27                   Police          SENIOR POLICE OFFICER  75942.10
# 2006-01-23                   Police          SENIOR POLICE OFFICER  69355.26
# ...                             ...                            ...       ...
# 2001-12-03                   Police          SENIOR POLICE OFFICER  75942.10
# 2016-03-28                    Other  SENIOR PROCUREMENT SPECIALIST  76175.00
# 2015-09-14     Houston Public Works      WATER SERVICE INSPECTOR I  35173.00
# 2008-05-19  Health & Human Services  HUMAN SERVICE PROGRAM MANAGER  67198.00
# 1984-05-29                   Police                POLICE SERGEANT       NaN
#
#                sex      race
# hire_date
# 2001-12-03    Male     White
# 2010-11-15    Male  Hispanic
# 2006-01-09    Male     Black
# 1997-05-27    Male  Hispanic
# 2006-01-23    Male     White
# ...            ...       ...
# 2001-12-03    Male     Black
# 2016-03-28  Female     Black
# 2015-09-14    Male     Black
# 2008-05-19  Female     Black
# 1984-05-29    Male     White
#
# [24308 rows x 5 columns]

# %%
emp.asfreq('Y')
# Out:
# C:\Users\nealv\AppData\Local\Temp\ipykernel_54096\2554006186.py:1: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   emp.asfreq('Y')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 emp.asfreq('Y')
#
# File c:\Users\nealv\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:9250, in NDFrame.asfreq(self, freq, method, how, normalize, fill_value)
#    9143 """
#    9144 Convert time series to specified frequency.
#    9145
#    (...)
#    9246 2000-01-01 00:03:00    3.0
#    9247 """
#    9248 from pandas.core.resample import asfreq
# -> 9250 return asfreq(
#    9251     self,
#    9252     freq,
#    9253     method=method,
#    9254     how=how,
#    9255     normalize=normalize,
#    9256     fill_value=fill_value,
#    9257 )
#
# File c:\Users\nealv\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\resample.py:2837, in asfreq(obj, freq, method, how, normalize, fill_value)
#    2835 dti = date_range(obj.index.min(), obj.index.max(), freq=freq, unit=unit)
#    2836 dti.name = obj.index.name
# -> 2837 new_obj = obj.reindex(dti, method=method, fill_value=fill_value)
#    2838 if normalize:
#    2839     new_obj.index = new_obj.index.normalize()
#
# File c:\Users\nealv\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5385, in DataFrame.reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5366 @doc(
#    5367     NDFrame.reindex,
#    5368     klass=_shared_doc_kwargs["klass"],
#    (...)
#    5383     tolerance=None,
#    5384 ) -> DataFrame:
# -> 5385     return super().reindex(
#    5386         labels=labels,
#    5387         index=index,
#    5388         columns=columns,
#    5389         axis=axis,
#    5390         method=method,
#    5391         copy=copy,
#    5392         level=level,
#    5393         fill_value=fill_value,
#    5394         limit=limit,
#    5395         tolerance=tolerance,
#    5396     )
#
# File c:\Users\nealv\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:5629, in NDFrame.reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5626     return self._reindex_multi(axes, copy, fill_value)
#    5628 # perform the reindex on the axes
# -> 5629 return self._reindex_axes(
#    5630     axes, level, limit, tolerance, method, fill_value, copy
#    5631 ).__finalize__(self, method="reindex")
#
# File c:\Users\nealv\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:5652, in NDFrame._reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    5649     continue
#    5651 ax = self._get_axis(a)
# -> 5652 new_index, indexer = ax.reindex(
#    5653     labels, level=level, limit=limit, tolerance=tolerance, method=method
#    5654 )
#    5656 axis = self._get_axis_number(a)
#    5657 obj = obj._reindex_with_indexers(
#    5658     {axis: [new_index, indexer]},
#    5659     fill_value=fill_value,
#    5660     copy=copy,
#    5661     allow_dups=False,
#    5662 )
#
# File c:\Users\nealv\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:4436, in Index.reindex(self, target, method, level, limit, tolerance)
#    4433     raise ValueError("cannot handle a non-unique multi-index!")
#    4434 elif not self.is_unique:
#    4435     # GH#42568
# -> 4436     raise ValueError("cannot reindex on an axis with duplicate labels")
#    4437 else:
#    4438     indexer, _ = self.get_indexer_non_unique(target)
#
# ValueError: cannot reindex on an axis with duplicate labels

# %% [markdown]
# Let's try and make it more like a time series by sorting the index.

# %%
emp = emp.sort_index()
emp.head(3)
# Out:
#               dept                            title   salary     sex      race
# hire_date
# 1968-12-13  Police            SENIOR POLICE OFFICER      NaN    Male     Black
# 1969-03-21  Police                  POLICE SERGEANT      NaN    Male  Hispanic
# 1969-10-06   Other  SENIOR PUBLIC LOSS INVESTIGATOR  75067.0  Female     White

# %% [markdown]
# The operation will only be successful if there are no duplicate dates. The error tells us that at least one hire date is not unique.

# %%
emp.asfreq('M')
# Out:
# C:\Users\nealv\AppData\Local\Temp\ipykernel_54096\300534979.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   emp.asfreq('M')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 emp.asfreq('M')
#
# File c:\Users\nealv\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:9250, in NDFrame.asfreq(self, freq, method, how, normalize, fill_value)
#    9143 """
#    9144 Convert time series to specified frequency.
#    9145
#    (...)
#    9246 2000-01-01 00:03:00    3.0
#    9247 """
#    9248 from pandas.core.resample import asfreq
# -> 9250 return asfreq(
#    9251     self,
#    9252     freq,
#    9253     method=method,
#    9254     how=how,
#    9255     normalize=normalize,
#    9256     fill_value=fill_value,
#    9257 )
#
# File c:\Users\nealv\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\resample.py:2837, in asfreq(obj, freq, method, how, normalize, fill_value)
#    2835 dti = date_range(obj.index.min(), obj.index.max(), freq=freq, unit=unit)
#    2836 dti.name = obj.index.name
# -> 2837 new_obj = obj.reindex(dti, method=method, fill_value=fill_value)
#    2838 if normalize:
#    2839     new_obj.index = new_obj.index.normalize()
#
# File c:\Users\nealv\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5385, in DataFrame.reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5366 @doc(
#    5367     NDFrame.reindex,
#    5368     klass=_shared_doc_kwargs["klass"],
#    (...)
#    5383     tolerance=None,
#    5384 ) -> DataFrame:
# -> 5385     return super().reindex(
#    5386         labels=labels,
#    5387         index=index,
#    5388         columns=columns,
#    5389         axis=axis,
#    5390         method=method,
#    5391         copy=copy,
#    5392         level=level,
#    5393         fill_value=fill_value,
#    5394         limit=limit,
#    5395         tolerance=tolerance,
#    5396     )
#
# File c:\Users\nealv\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:5629, in NDFrame.reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5626     return self._reindex_multi(axes, copy, fill_value)
#    5628 # perform the reindex on the axes
# -> 5629 return self._reindex_axes(
#    5630     axes, level, limit, tolerance, method, fill_value, copy
#    5631 ).__finalize__(self, method="reindex")
#
# File c:\Users\nealv\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:5652, in NDFrame._reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    5649     continue
#    5651 ax = self._get_axis(a)
# -> 5652 new_index, indexer = ax.reindex(
#    5653     labels, level=level, limit=limit, tolerance=tolerance, method=method
#    5654 )
#    5656 axis = self._get_axis_number(a)
#    5657 obj = obj._reindex_with_indexers(
#    5658     {axis: [new_index, indexer]},
#    5659     fill_value=fill_value,
#    5660     copy=copy,
#    5661     allow_dups=False,
#    5662 )
#
# File c:\Users\nealv\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:4436, in Index.reindex(self, target, method, level, limit, tolerance)
#    4433     raise ValueError("cannot handle a non-unique multi-index!")
#    4434 elif not self.is_unique:
#    4435     # GH#42568
# -> 4436     raise ValueError("cannot reindex on an axis with duplicate labels")
#    4437 else:
#    4438     indexer, _ = self.get_indexer_non_unique(target)
#
# ValueError: cannot reindex on an axis with duplicate labels

# %% [markdown]
# Selection with partial string still works.

# %%
emp.loc['2012-1':'2012-2'].head()
# Out:
#                                dept                                   title  \
# hire_date
# 2012-01-03                    Other                          COUNCIL MEMBER
# 2012-01-03                    Other                          COUNCIL MEMBER
# 2012-01-03                    Other       DEPUTY DIRECTOR (EXECUTIVE LEVEL)
# 2012-01-03                   Police           CRIMINAL INTELLIGENCE ANALYST
# 2012-01-03  Health & Human Services  SURVEILLANCE INVESTIGATOR-EPIDEMIOLOGY
#
#               salary     sex   race
# hire_date
# 2012-01-03   62983.0  Female  White
# 2012-01-03   62983.0    Male  White
# 2012-01-03  142170.0  Female  Black
# 2012-01-03   59322.0    Male  White
# 2012-01-03   46654.0  Female  Black

# %% [markdown]
# ## Exercises

# %%
import pandas as pd
import numpy as np

# ------------------------------------------------------------------------------
# 1. ROBUST INGESTION MODULE
# ------------------------------------------------------------------------------
def load_weather_production(path: str) -> pd.DataFrame:
    """
    Ingests weather data with maximum safety.
    
    Standards Applied:
    1. .replace(): Non-destructive transformation. Preserves unexpected values.
    2. 'boolean': Nullable type. Allows True/False/NA (unlike numpy bool).
    3. Method Chaining: Atomic steps.
    """
    # Define mapping dictionary
    yes_no_map = {'Yes': True, 'No': False}
    
    return (pd.read_csv(path)
        .assign(
            # 1. Date: Convert and Index
            date=lambda x: pd.to_datetime(x['date']),
            
            # 2. Rain/Snow: The Safe Transformation
            # We use .replace() so we don't destroy data we didn't expect.
            # We use .astype('boolean') to handle missing values safely.
            rain=lambda x: x['rain'].replace(yes_no_map).astype('boolean'),
            snow=lambda x: x['snow'].replace(yes_no_map).astype('boolean'),
            
            # 3. Temp: Force numeric, turning errors into NaNs (safely)
            temperature=lambda x: pd.to_numeric(x['temperature'], errors='coerce')
        )
        .set_index('date')
        .sort_index()
    )

# Load Data (Simulated path for MDA repo)
weather = load_weather_production('../data/weather.csv')
# Out:
# C:\Users\nealv\AppData\Local\Temp\ipykernel_54096\1001876187.py:27: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   rain=lambda x: x['rain'].replace(yes_no_map).astype('boolean'),
# C:\Users\nealv\AppData\Local\Temp\ipykernel_54096\1001876187.py:28: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   snow=lambda x: x['snow'].replace(yes_no_map).astype('boolean'),

# %%
weather
# Out:
#              rain   snow  temperature
# date
# 2007-01-01   True  False         68.0
# 2007-01-02  False  False         55.9
# 2007-01-03  False  False         62.1
# 2007-01-04  False  False         69.1
# 2007-01-05   True  False         72.0
# ...           ...    ...          ...
# 2018-11-20  False  False         64.0
# 2018-11-21  False  False         57.0
# 2018-11-22  False  False         50.0
# 2018-11-23  False  False         45.0
# 2018-11-24  False  False         45.0
#
# [4346 rows x 3 columns]

# %% [markdown]
# ### Exercise 1
#
# <span style="color:green; font-size:16px">Read in the weather time series dataset and place the date column in the index. Then use this DataFrame for the following questions.</span>

# %%
weather.index
# Out:
# DatetimeIndex(['2007-01-01', '2007-01-02', '2007-01-03', '2007-01-04',
#                '2007-01-05', '2007-01-06', '2007-01-07', '2007-01-08',
#                '2007-01-09', '2007-01-10',
#                ...
#                '2018-11-15', '2018-11-16', '2018-11-17', '2018-11-18',
#                '2018-11-19', '2018-11-20', '2018-11-21', '2018-11-22',
#                '2018-11-23', '2018-11-24'],
#               dtype='datetime64[ns]', name='date', length=4346, freq=None)

# %% [markdown]
# ### Exercise 2
#
# <span style="color:green; font-size:16px">Select all of the month of November, 2010</span>

# %%
weather.loc['2010-11'].head(3)
# Out:
#              rain   snow  temperature
# date
# 2010-11-01  False  False         63.0
# 2010-11-02  False  False         57.9
# 2010-11-03   True  False         55.9

# %% [markdown]
# ### Exercise 3
#
# <span style="color:green; font-size:16px">Select all of the second quarter of 2017.</span>

# %%
q2_2017 = weather.loc['2017-04':'2017-06']

# %%
weather.loc['2017Q2']
# Out:
#              rain   snow  temperature
# date
# 2017-04-01  False  False         75.0
# 2017-04-02  False  False         69.1
# 2017-04-03  False  False         75.9
# 2017-04-04  False  False         82.0
# 2017-04-05  False  False         78.1
# ...           ...    ...          ...
# 2017-06-26  False  False         84.9
# 2017-06-27  False  False         82.9
# 2017-06-28  False  False         82.9
# 2017-06-29  False  False         87.1
# 2017-06-30  False  False         87.1
#
# [91 rows x 3 columns]

# %% [markdown]
# ### Exercise 4
#
# <span style="color:green; font-size:16px">Select data from July 1, 2015 to the end of 2016.</span>

# %%
mid_15_to_16 = weather.loc['2015-07-01':'2016']
mid_15_to_16
# Out:
#              rain   snow  temperature
# date
# 2015-07-01  False  False         87.1
# 2015-07-02  False  False         87.1
# 2015-07-03  False  False         78.1
# 2015-07-04  False  False         87.1
# 2015-07-05  False  False         90.0
# ...           ...    ...          ...
# 2016-12-27  False  False         68.0
# 2016-12-28  False  False         60.1
# 2016-12-29  False  False         63.0
# 2016-12-30  False  False         48.0
# 2016-12-31  False  False         50.0
#
# [550 rows x 3 columns]

# %%
weather.loc['2015Q3':'2016']
# Out:
#              rain   snow  temperature
# date
# 2015-07-01  False  False         87.1
# 2015-07-02  False  False         87.1
# 2015-07-03  False  False         78.1
# 2015-07-04  False  False         87.1
# 2015-07-05  False  False         90.0
# ...           ...    ...          ...
# 2016-12-27  False  False         68.0
# 2016-12-28  False  False         60.1
# 2016-12-29  False  False         63.0
# 2016-12-30  False  False         48.0
# 2016-12-31  False  False         50.0
#
# [550 rows x 3 columns]

# %% [markdown]
# ### Exercise 5
#
# <span style="color:green; font-size:16px">Select just the rain and snow columns from the January 1, 2008 to January 7, 2008.</span>

# %%
weather.loc['2008-01-01':'2008-01-07', ['rain', 'snow']]
# Out:
#              rain   snow
# date
# 2008-01-01  False  False
# 2008-01-02  False   True
# 2008-01-03  False  False
# 2008-01-04  False  False
# 2008-01-05  False  False
# 2008-01-06  False  False
# 2008-01-07  False  False

# %% [markdown]
# ### Exercise 6
#
# <span style="color:green; font-size:16px">What was the temperature on June 11, 2011?</span>

# %%
weather.loc['2011-06-11','temperature']
# Out:
# np.float64(93.9)

# %% [markdown]
# ### Exercise 7
#
# <span  style="color:green; font-size:16px">How many days did it rain during the last three months of 2011?</span>

# %%
rainy_days = (weather
    .loc['2011-10':'2011-12', 'rain']
    .gt(0)
    .sum()
)

rainy_days
# Out:
# np.int64(23)

# %%
rainy_days = (weather
    .loc['2011Q4', 'rain']
    .sum()
)
# Out:
# np.int64(23)

# %% [markdown]
# ### Exercise 8
#
# <span style="color:green; font-size:16px">Which year had more snow days, 2007 or 2012?</span>

# %%
snow_07 = weather.loc['2007', 'snow'].sum()
snow_12 = weather.loc['2012', 'snow'].sum()
more_snow_year = 2007 if snow_07 > snow_12 else 2012

more_snow_year
# Out:
# 2007

# %%
more_snow_year = (
    weather
    .loc[lambda df_: df_.index.year.isin([2007,2012]),'snow']
    .groupby(lambda idx: idx.year)  
    .sum()                        
)

more_snow_year.idxmax()
# Out:
# np.int64(2007)

# %% [markdown]
# ### Exercise 9
#
# <span style="color:green; font-size:16px">Select every other Thursday.</span>

# %%
biweekly_thursdays = (
    weather       # Required for performance and reindexing safety
    .asfreq('2W-THU')       # Selects every 2nd week, anchored on Thursday
)

# %% [markdown]
# ### Exercise 10
#
# <span style="color:green; font-size:16px">Select the first day of each month.</span>

# %%
weather.asfreq('MS')
# Out:
#              rain   snow  temperature
# date
# 2007-01-01   True  False         68.0
# 2007-02-01   True   True         34.0
# 2007-03-01   True  False         66.9
# 2007-04-01   True  False         77.0
# 2007-05-01  False  False         91.9
# ...           ...    ...          ...
# 2018-07-01  False  False         95.0
# 2018-08-01  False  False         90.0
# 2018-09-01  False  False         93.0
# 2018-10-01  False  False         82.0
# 2018-11-01  False  False         75.0
#
# [143 rows x 3 columns]

# %% [markdown]
# ### Exercise 11
#
# <span style="color:green; font-size:16px">Select every other October 1st.</span>

# %%
weather.asfreq('2YS-OCT')
# Out:
#              rain   snow  temperature
# date
# 2007-10-01  False  False         82.0
# 2009-10-01  False  False         73.0
# 2011-10-01  False  False         64.0
# 2013-10-01  False  False         82.0
# 2015-10-01  False  False         66.0
# 2017-10-01  False  False         71.1

# %% [markdown]
# ### Use the temperature dataset for the remaining exercises
#
# Execute the following cell to read in the temperature dataset which sets the datetime column in the index.

# %%
df_temp = pd.read_csv('../data/weather/temperature.csv', parse_dates=['datetime'], 
                      index_col='datetime')
df_temp.head()
# Out:
#                      Seattle  San Francisco  Los Angeles  Las Vegas  Denver  \
# datetime
# 2013-01-01 00:00:00     2.94          11.50        11.66       7.28   -2.30
# 2013-01-01 01:00:00     2.40          10.22        10.67       5.95   -3.23
# 2013-01-01 02:00:00     1.70           8.02         9.91       5.18   -3.03
# 2013-01-01 03:00:00     1.45           7.30         9.33       4.42   -3.67
# 2013-01-01 04:00:00     0.95           6.84         8.82       3.62   -5.55
#
#                      Houston  Chicago  Atlanta  Miami  New York
# datetime
# 2013-01-01 00:00:00     8.81    -0.19     1.92  19.41     -1.12
# 2013-01-01 01:00:00     8.81     0.28     0.60  19.35     -1.69
# 2013-01-01 02:00:00     8.81     0.33    -0.53  18.99     -1.96
# 2013-01-01 03:00:00     8.48     0.12    -1.36  18.56     -2.08
# 2013-01-01 04:00:00     8.34     0.04    -1.44  18.49     -2.32

# %% [markdown]
# ### Exercise 12
#
# <span style="color:green; font-size:16px">Select the temperatures for Houston between 3 and 6 p.m. on July 4, 2014.</span>

# %%
houston_temp = df_temp.loc['2014-07-04 15:00':'2014-07-04 18:00', 'Houston']

# %% [markdown]
# ### Exercise 13
#
# <span style="color:green; font-size:16px">Upsample the result from the previous exercise so that there are entries every 20 minutes.</span>

# %%
houston_temp.asfreq('20T')
# Out:
# C:\Users\nealv\AppData\Local\Temp\ipykernel_54096\799579359.py:1: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   houston_temp.asfreq('20T')
# datetime
# 2014-07-04 15:00:00    27.37
# 2014-07-04 15:20:00      NaN
# 2014-07-04 15:40:00      NaN
# 2014-07-04 16:00:00    28.85
# 2014-07-04 16:20:00      NaN
# 2014-07-04 16:40:00      NaN
# 2014-07-04 17:00:00    30.29
# 2014-07-04 17:20:00      NaN
# 2014-07-04 17:40:00      NaN
# 2014-07-04 18:00:00    31.00
# Freq: 20min, Name: Houston, dtype: float64

# %% [markdown]
# ### Exercise 14
#
# <span style="color:green; font-size:16px">Linearly interpolate the missing values in the previous exercise to estimate the temperature at 4:40 pm on July 4, 2014.</span>

# %%
houston_temp.asfreq('20min').interpolate(method='linear')
# Out:
# datetime
# 2014-07-04 15:00:00    27.370000
# 2014-07-04 15:20:00    27.863333
# 2014-07-04 15:40:00    28.356667
# 2014-07-04 16:00:00    28.850000
# 2014-07-04 16:20:00    29.330000
# 2014-07-04 16:40:00    29.810000
# 2014-07-04 17:00:00    30.290000
# 2014-07-04 17:20:00    30.526667
# 2014-07-04 17:40:00    30.763333
# 2014-07-04 18:00:00    31.000000
# Freq: 20min, Name: Houston, dtype: float64
