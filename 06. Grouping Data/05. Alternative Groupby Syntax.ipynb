# %% [markdown]
# # Alternative Groupby Syntax
#
# This chapter covers a few other alternative syntaxes available to do aggregations with the `groupby` method. This chapter has potential to confuse beginning pandas users since these methods do not give you any extra power to do data analysis. However, many other people who use pandas will use these syntaxes so it's important to be aware that they exist. Let's begin by reading in the San Francisco employee compensation dataset.

# %%
import pandas as pd
import numpy as np
sf_emp = pd.read_csv('../data/sf_employee_compensation.csv')
sf_emp.head(3)
# Out:
#    year                organization group                   job   salaries  \
# 0  2013                 Public Protection  Personnel Technician   71414.01
# 1  2013  General Administration & Finance             Planner 2   67941.06
# 2  2013                 Public Protection           Firefighter  116956.72
#
#    overtime  other salaries  retirement  health and dental  other benefits
# 0      0.00             0.0    14038.58           12918.24         5872.04
# 1      0.00             0.0    13030.23           10047.52         5608.37
# 2  59975.43         19037.3    24796.44           15788.97         3222.20

# %% [markdown]
# ## Aggregating a single column
#
# Originally, we set our new column name equal to a two-item tuple of the aggregating column and the aggregating function within the `agg` method.

# %%
sf_emp.groupby('organization group').agg(mean_salary=('salaries', 'mean'))
# Out:
#                                            mean_salary
# organization group
# Community Health                          59002.519797
# Culture & Recreation                      29496.244217
# General Administration & Finance          59452.791117
# General City Responsibilities             33787.559971
# Human Welfare & Neighborhood Development  44410.937355
# Public Protection                         77298.638409
# Public Works, Transportation & Commerce   57852.310785

# %% [markdown]
# ### Alternative - use a dictionary
#
# Instead of a tuple, you can use a dictionary to map the aggregating column to the aggregating function. The generic syntax takes on the following form:
#
# ```python
# df.groupby('grouping column').agg({'aggregating column': 'aggregating function'})
# ```
#
#
# Although this syntax uses less code, it does not allow you to rename columns during the aggregation.

# %%
sf_emp.groupby('organization group').agg({'salaries': 'mean'})
# Out:
#                                               salaries
# organization group
# Community Health                          59002.519797
# Culture & Recreation                      29496.244217
# General Administration & Finance          59452.791117
# General City Responsibilities             33787.559971
# Human Welfare & Neighborhood Development  44410.937355
# Public Protection                         77298.638409
# Public Works, Transportation & Commerce   57852.310785

# %% [markdown]
# ### Alternative - select the column with the brackets
#
# Instead of using a dictionary, place the aggregating columns in brackets following the `groupby` method and then pass the aggregating function as a string to the `agg` method. The generic syntax takes on the following form:
#
# ```python
# df.groupby('grouping column')['aggregating column'].agg('aggregating function')
# ```

# %%
sf_emp.groupby('organization group')['salaries'].agg('mean')
# Out:
# organization group
# Community Health                            59002.519797
# Culture & Recreation                        29496.244217
# General Administration & Finance            59452.791117
# General City Responsibilities               33787.559971
# Human Welfare & Neighborhood Development    44410.937355
# Public Protection                           77298.638409
# Public Works, Transportation & Commerce     57852.310785
# Name: salaries, dtype: float64

# %% [markdown]
# You can even bypass the `agg` method and use the name of the aggregation as a method directly after the brackets.

# %%
sf_emp.groupby('organization group')['salaries'].mean()
# Out:
# organization group
# Community Health                            59002.519797
# Culture & Recreation                        29496.244217
# General Administration & Finance            59452.791117
# General City Responsibilities               33787.559971
# Human Welfare & Neighborhood Development    44410.937355
# Public Protection                           77298.638409
# Public Works, Transportation & Commerce     57852.310785
# Name: salaries, dtype: float64

# %%
sf_emp.groupby('organization group')[['salaries']].mean()
# Out:
#                                               salaries
# organization group
# Community Health                          59002.519797
# Culture & Recreation                      29496.244217
# General Administration & Finance          59452.791117
# General City Responsibilities             33787.559971
# Human Welfare & Neighborhood Development  44410.937355
# Public Protection                         77298.638409
# Public Works, Transportation & Commerce   57852.310785

# %% [markdown]
# ### Possible advantage - allows for multiple aggregating columns
#
# Using any of these alternative methods allows you to use multiple aggregating functions with less amount of code. Here, we use a dictionary to make the aggregating column to all of the aggregating functions we desire.

# %%
sf_emp.groupby('organization group').agg({'salaries': ['mean', 'min', 'max']})
# Out:
#                                               salaries
#                                                   mean      min        max
# organization group
# Community Health                          59002.519797 -2716.50  284024.31
# Culture & Recreation                      29496.244217     0.00  237551.67
# General Administration & Finance          59452.791117 -1683.60  301104.04
# General City Responsibilities             33787.559971     0.00  365749.75
# Human Welfare & Neighborhood Development  44410.937355 -1119.86  221076.01
# Public Protection                         77298.638409 -2984.52  645739.46
# Public Works, Transportation & Commerce   57852.310785 -1461.50  253688.17

# %% [markdown]
# We would need to use more code with the original syntax, but I prefer this as we are returned a DataFrame with a single level index for the columns and we can name each column exactly what we desire.

# %%
sf_emp.groupby('organization group').agg(mean_salary=('salaries', 'mean'),
                                         min_salary=('salaries', 'min'),
                                         max_salary=('salaries', 'max'))

# %%
sf_emp.groupby('organization group').agg({'salaries': ['mean', 'min', 'max'], 'overtime':['mean','min','max']})
# Out:
#                                               salaries                      \
#                                                   mean      min        max
# organization group
# Community Health                          59002.519797 -2716.50  284024.31
# Culture & Recreation                      29496.244217     0.00  237551.67
# General Administration & Finance          59452.791117 -1683.60  301104.04
# General City Responsibilities             33787.559971     0.00  365749.75
# Human Welfare & Neighborhood Development  44410.937355 -1119.86  221076.01
# Public Protection                         77298.638409 -2984.52  645739.46
# Public Works, Transportation & Commerce   57852.310785 -1461.50  253688.17
#
#                                               overtime
#                                                   mean       min        max
# organization group
# Community Health                           2019.964453 -18458.15   78206.57
# Culture & Recreation                        833.305678    -45.56  100443.69
# General Administration & Finance            760.437942   -188.52   42005.20
# General City Responsibilities              3071.330640      0.00  214556.62
# Human Welfare & Neighborhood Development    655.851562      0.00   41581.89
# Public Protection                         11517.841398      0.00  258124.17
# Public Works, Transportation & Commerce    5069.196369    -48.00  152088.80

# %% [markdown]
# ## No Aggregating Columns
#
# You actually do not need to specify the aggregating columns when grouping if using the method version of the aggregation. When doing so, all columns will be aggregated. Here, we set `numeric_only` to `True` to ensure that only the numeric columns are aggregated by the mean.

# %%
(sf_emp.groupby(['year', 'organization group'])
       .mean(numeric_only=True)
       .head()
       .round(-3))
# Out:
#                                                salaries  overtime  \
# year organization group
# 2013 Community Health                           59000.0    2000.0
#      Culture & Recreation                       31000.0    1000.0
#      General Administration & Finance           65000.0    1000.0
#      General City Responsibilities              13000.0    2000.0
#      Human Welfare & Neighborhood Development   50000.0       0.0
#
#                                                other salaries  retirement  \
# year organization group
# 2013 Community Health                                  4000.0     11000.0
#      Culture & Recreation                              1000.0      5000.0
#      General Administration & Finance                  1000.0     12000.0
#      General City Responsibilities                     2000.0      3000.0
#      Human Welfare & Neighborhood Development          1000.0      9000.0
#
#                                                health and dental  \
# year organization group
# 2013 Community Health                                     8000.0
#      Culture & Recreation                                 6000.0
#      General Administration & Finance                     9000.0
#      General City Responsibilities                        3000.0
#      Human Welfare & Neighborhood Development             9000.0
#
#                                                other benefits
# year organization group
# 2013 Community Health                                  5000.0
#      Culture & Recreation                              3000.0
#      General Administration & Finance                  5000.0
#      General City Responsibilities                     1000.0
#      Human Welfare & Neighborhood Development          4000.0

# %% [markdown]
# ## Exercises

# %% [markdown]
# Execute the cell below to read in the flights dataset and then use it for the following exercises.

# %%
import pandas as pd
flights = pd.read_csv('../data/flights.csv', parse_dates=['date'])
flights.head(3)
# Out:
#         date airline origin dest  dep_time  arr_time  cancelled  air_time  \
# 0 2018-01-01      UA    LAS  IAH       100       547          0     134.0
# 1 2018-01-01      WN    DEN  PHX       515       720          0      91.0
# 2 2018-01-01      B6    JFK  BOS       550       657          0      39.0
#
#    distance  carrier_delay  weather_delay  nas_delay  security_delay  \
# 0    1222.0              0              0          0               0
# 1     602.0              0              0          0               0
# 2     187.0              0             83          8               0
#
#    late_aircraft_delay
# 0                    0
# 1                    0
# 2                    0

# %% [markdown]
# ### Exercise 1
#
# <span style="color:green; font-size:16px">Use a dictionary in the `groupby` `agg` method to calculate the mean, median, min, and max of the air time for every airline.</span>

# %%
flights.groupby('airline').agg({'air_time':['mean','median','min','max']})
# Out:
#            air_time
#                mean median   min    max
# airline
# 9E        89.901705   84.0  24.0  224.0
# AA       147.940078  126.0  22.0  421.0
# AS       185.414344  149.0  38.0  395.0
# B6       170.061845  132.0  32.0  428.0
# DL       146.034775  125.0  22.0  405.0
# EV        57.440252   45.0  35.0  178.0
# F9       139.187223  124.0  55.0  327.0
# MQ        80.218130   83.0  20.0  164.0
# NK       147.173162  133.0  40.0  388.0
# OH        66.418699   70.5  28.0  142.0
# OO        98.228543   92.0  38.0  266.0
# UA       160.476621  138.0  33.0  422.0
# VX       178.189189  132.0  38.0  427.0
# WN       112.839452   95.0  36.0  344.0
# YV       121.506294  130.0  38.0  231.0
# YX        93.165300   83.0  21.0  258.0

# %% [markdown]
# ### Exercise 2
#
# <span style="color:green; font-size:16px">Without using the `agg` method calculate the number of unique destinations for each airline.</span>

# %%
flights.groupby('airline')['dest'].nunique()
# Out:
# airline
# 9E    13
# AA    20
# AS    18
# B6    19
# DL    20
# EV     8
# F9    17
# MQ    12
# NK    16
# OH     9
# OO    19
# UA    19
# VX    12
# WN    15
# YV    10
# YX    14
# Name: dest, dtype: int64

# %% [markdown]
# ### Exercise 3
#
# <span style="color:green; font-size:16px">Calculate the mean of every numeric column for each airline and origin without using the `agg` method.</span>

# %%
flights.groupby(['airline','origin']).mean(numeric_only=True)
# Out:
#                    dep_time     arr_time  cancelled    air_time     distance  \
# airline origin
# 9E      ATL      729.714286   840.142857   0.000000  105.142857   689.000000
#         BOS     1320.029412  1453.970588   0.049020   47.103093   191.558824
#         CLT     1254.613636  1461.238636   0.068182   82.926829   554.397727
#         DCA     1168.218182  1309.563636   0.018182   44.629630   216.490909
#         DFW     1346.068182  1682.136364   0.011364  137.080460  1054.022727
# ...                     ...          ...        ...         ...          ...
# YX      JFK     1519.901961  1677.705882   0.078431   57.191489   278.725490
#         LGA     1272.184569  1456.931921   0.046899   91.452229   546.311649
#         MSP     1167.055556  1494.888889   0.037037  114.737179   843.049383
#         ORD     1374.639535  1515.186047   0.027132   86.163347   589.135659
#         PHL     1515.984375  1690.390625   0.000000   71.359375   391.703125
#
#                 carrier_delay  weather_delay  nas_delay  security_delay  \
# airline origin
# 9E      ATL          0.000000       0.000000   3.857143             0.0
#         BOS          2.284314       0.029412   8.607843             0.0
#         CLT          5.261364       0.000000   4.022727             0.0
#         DCA         10.945455       0.000000   1.309091             0.0
#         DFW          2.840909       0.738636   3.772727             0.0
# ...                       ...            ...        ...             ...
# YX      JFK          0.000000       0.000000   3.078431             0.0
#         LGA          3.028744       0.422088   3.836611             0.0
#         MSP          1.265432       0.037037   7.962963             0.0
#         ORD          2.093023       0.352713   7.015504             0.0
#         PHL          3.984375       0.031250   2.140625             0.0
#
#                 late_aircraft_delay
# airline origin
# 9E      ATL                0.000000
#         BOS                4.176471
#         CLT                4.295455
#         DCA                2.163636
#         DFW               11.875000
# ...                             ...
# YX      JFK                2.980392
#         LGA                4.751891
#         MSP                5.067901
#         ORD                7.569767
#         PHL                4.000000
#
# [240 rows x 10 columns]
